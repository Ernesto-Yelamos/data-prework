# %% [markdown]
# <img src="https://bit.ly/2VnXWr2" width="100" align="left">

# %% [markdown]
# # Rock, Paper & Scissors
#
# Let's play the famous game against our computer. You can check the rules [here](https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors).
#
# ## Task
# Create a program that imitates the playability of the well known game of rock, paper, scissors. Follow the guidelines provided.
#
# ## Tools
# 1. Loop: **for/while**
# 2. Functions: **input(), print()...**
# 3. Conditional statements: **if, elif, else**
# 4. Definition of functions. Modular programming
# 5. Import modules
#
# **To solve this challenge, the use of functions is recommended.**
#
# #### 1. Import the choice function of the random module.

# %%
import random

# %% [markdown]
# #### 2. Create a list that includes the 3 possible gesture options of the game: 'rock', 'paper' or 'scissors'. Store the list in a variable called `gestures`.

# %%
gestures = ['rock', 'paper', 'scissors']

# %% [markdown]
# #### 3. Create a variable called `n_rounds` to store the maximum number of rounds to play in a game.
# Remember that the number of rounds must be odd: 1, 3, 5, ...

# %%
n_rounds = 3

# %% [markdown]
# #### 4. Create a variable called `rounds_to_win` to store the number of rounds that a player must win to win the game.
# **Hint**: the value stored in `rounds_to_win` depends on the value of `n_rounds`.

# %%
rounds_to_win = n_rounds - 1

# %% [markdown]
# #### 5. Create two variables to store the number of rounds that the computer and the player have won. Call these variables `cpu_score` and `player_score`.

# %%
cpu_score = 0
player_score = 0

# %% [markdown]
# #### 6. Define a function that randomly returns one of the 3 gesture options.
# You will use this function to simulate the gesture choice of the computer.

# %%
def CPU_choice():
    cpu_choice = random.choice(gestures)
    return cpu_choice

# %% [markdown]
# #### 7. Define a function that asks the player which is the gesture he or she wants to show: 'rock', 'paper' or 'scissors'.
# The player should only be allowed to choose one of the 3 gesture options. If the player's choice is not rock, paper or scissors, keep asking until it is.

# %%
def PLAYER_choice():
    player_choice = input("Choose rock, paper or scissors: ")
    if player_choice in ["Rock", "rock", "r", "R"]:
        player_choice = 'rock'
    elif player_choice in ["Paper", "paper", "p", "P"]:
        player_choice = 'paper'
    elif player_choice in ["Scissors", "scissors", "s", "S"]:
        player_choice = 'scissors'
    else:
        print("Invalid answer. Please try again.")
        PLAYER_choice()
    return player_choice

# %% [markdown]
# #### 8. Define a function that checks who won a round.
# The function should return 0 if there is a tie, 1 if the computer wins and 2 if the player wins.

# %%
def winner_round(cpu_choice, player_choice):
    global cpu_score
    global player_score
    if player_choice == cpu_choice:
        cpu_score += 0
        player_score += 0
    elif player_choice == 'rock':
        if cpu_choice == 'paper':
            cpu_score += 1
        if cpu_choice == 'scissors':
            player_score += 1
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            player_score += 1
        if cpu_choice == 'scissors':
            cpu_score += 1
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            cpu_score += 1
        if cpu_choice == 'paper':
            player_score += 1

# %% [markdown]
# #### 9. Define a function that prints the choice of the computer, the choice of the player and a message that announces who won the current round.
# You should also use this function to update the variables that count the number of rounds that the computer and the player have won. The score of the winner increases by one point. If there is a tie, the score does not increase.

# %%
def print_winner_round():
    if player_choice == 'rock':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses rock. This round is a tie.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses rock. Cpu wins this round.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses rock. Player wins this round.")
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses paper. Player wins this round.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses paper. This round is a tie.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses paper. Cpu wins this round.")
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses scissors. Cpu wins this round.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses scissors. Player wins this round.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses scissors. This round is a tie.")

# %% [markdown]
# #### 10. Now it's time to code the execution of the game using the functions and variables you defined above.
#
# First, create a loop structure that repeats while no player reaches the minimum score necessary to win and the number of rounds is less than the maximum number of rounds to play in a game.
#
# Inside the loop, use the functions and variables above to create the execution of a round: ask for the player's choice, generate the random choice of the computer, show the round results, update the scores, etc.

# %%
import random

gestures = ['rock', 'paper', 'scissors']

n_rounds = 5
rounds_to_win = n_rounds - 1
cpu_score = 0
player_score = 0
n = 0

def CPU_choice():
    cpu_choice = random.choice(gestures)
    return cpu_choice

def PLAYER_choice():
    player_choice = input("Choose rock, paper or scissors: ")
    if player_choice in ["Rock", "rock", "r", "R"]:
        player_choice = 'rock'
    elif player_choice in ["Paper", "paper", "p", "P"]:
        player_choice = 'paper'
    elif player_choice in ["Scissors", "scissors", "s", "S"]:
        player_choice = 'scissors'
    else:
        print("Invalid answer. Please try again.")
        PLAYER_choice()
    return player_choice

def winner_round(cpu_choice, player_choice):
    global cpu_score
    global player_score
    if player_choice == cpu_choice:
        cpu_score += 0
        player_score += 0
    elif player_choice == 'rock':
        if cpu_choice == 'paper':
            cpu_score += 1
        elif cpu_choice == 'scissors':
            player_score += 1
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            player_score += 1
        elif cpu_choice == 'scissors':
            cpu_score += 1
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            cpu_score += 1
        elif cpu_choice == 'paper':
            player_score += 1

def print_winner_round():
    if player_choice == 'rock':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses rock.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses rock.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses rock.")
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses paper.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses paper.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses paper.")
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses scissors.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses scissors.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses scissors.")

while n <= rounds_to_win:
    cpu_choice = CPU_choice()
    player_choice = PLAYER_choice()
    winner = winner_round(cpu_choice, player_choice)
    print_winner_round()
    n += 1
    if player_choice == 'rock':
        if cpu_choice == 'rock':
            print("This round is a tie.")
        elif cpu_choice == 'paper':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'scissors':
            print("Player wins this round.")
            player_score += 1
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            print("Player wins this round.")
            player_score += 1
        elif cpu_choice == 'paper':
            print("This round is a tie.")
        elif cpu_choice == 'scissors':
            print("Cpu wins this round.")
            cpu_score += 1
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'paper':
            print("Player wins this round.")
            player_score += 1
        elif cpu_choice == 'scissors':
            print("This round is a tie.")
    elif cpu_score == rounds_to_win:
            print("Cpu wins the game.")
    elif player_score == rounds_to_win:
            print("Player wins the game.")

# %% [markdown]
# #### 11. Print the winner of the game based on who won more rounds.
# Remember that the game might be tied.

# %%
if cpu_score == rounds_to_win:
    print("Cpu wins the game.")
elif player_score == rounds_to_win:
    print("Player wins the game.")
# Out:
# Cpu wins the game.

# %% [markdown]
# # Bonus: Rock, Paper, Scissors, Lizard & Spock
# ![](images/rpsls.jpg)
#
# In this challenge, you need to improve the previous game by adding two new options. To know more about the rules of the improved version of rock, paper, scissors, check this [link](http://www.samkass.com/theories/RPSSL.html).
#
# In addition, you will also need to improve how the game interacts with the player: the number of rounds to play, which must be an odd number, will be requested to the user until a valid number is entered. Define a new function to make that request.
#
# **Hint**: Try to reuse the code that you already coded in the previous challenge. If your code is efficient, this bonus will only consist of simple modifications to the original game.

# %%
import random

gestures = ['rock', 'paper', 'scissors', 'lizard', 'spock']

rounds_to_win = n_rounds - ((n_rounds/2) - 1/2)
cpu_score = 0
player_score = 0
n = 0

def number_rounds():
    while True:
        n_rounds = input('Choose number of rounds: ')
        try:
            n_rounds = int(n_rounds)
        except:
            print('Please use numeric digits.')
            continue
        if n_rounds % 2 == 0:
            print('Please select uneven number.')
            continue
        break
    return n_rounds

def CPU_choice():
    cpu_choice = random.choice(gestures)
    return cpu_choice

def PLAYER_choice():
    player_choice = input("Choose rock, paper, scissors, lizard or spock: ")
    if player_choice in ["Rock", "rock"]:
        player_choice = 'rock'
    elif player_choice in ["Paper", "paper"]:
        player_choice = 'paper'
    elif player_choice in ["Scissors", "scissors"]:
        player_choice = 'scissors'
    elif player_choice in ["Lizard", "lizard"]:
        player_choice = 'lizard'
    elif player_choice in ["Spock", "spock"]:
        player_choice = 'spock'
    else:
        print("Invalid answer. Please try again.")
        PLAYER_choice()
    return player_choice

def winner_round(cpu_choice, player_choice):
    global cpu_score
    global player_score
    if player_choice == cpu_choice:
        cpu_score += 0
        player_score += 0
    elif player_choice == 'rock':
        if cpu_choice == 'paper':
            cpu_score += 1
        elif cpu_choice == 'scissors':
            player_score += 1
        elif cpu_choice == 'lizard':
            player_score += 1
        elif cpu_choice == 'spock':
            cpu_score += 1
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            player_score += 1
        elif cpu_choice == 'scissors':
            cpu_score += 1
        elif cpu_choice == 'lizard':
            cpu_score += 1
        elif cpu_choice == 'spock':
            player_score += 1
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            cpu_score += 1
        elif cpu_choice == 'paper':
            player_score += 1
        elif cpu_choice == 'lizard':
            player_score += 1
        elif cpu_choice == 'spock':
            cpu_score += 1
    elif player_choice == 'lizard':
        if cpu_choice == 'rock':
            cpu_score += 1
        elif cpu_choice == 'paper':
            player_score += 1
        elif cpu_choice == 'scissors':
            cpu_score += 1
        elif cpu_choice == 'spock':
            player_score += 1
    elif player_choice == 'spock':
        if cpu_choice == 'rock':
            player_score += 1
        elif cpu_choice == 'paper':
            cpu_score += 1
        elif cpu_choice == 'scissors':
            player_score += 1
        elif cpu_choice == 'lizard':
            cpu_score += 1

def print_winner_round():
    if player_choice == 'rock':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses rock.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses rock.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses rock.")
        elif cpu_choice == 'lizard':
            print("Cpu chooses lizard, player chooses rock.")
        elif cpu_choice == 'spock':
            print("Cpu chooses spock, player chooses rock.")
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses paper.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses paper.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses paper.")
        elif cpu_choice == 'lizard':
            print("Cpu chooses lizard, player chooses paper.")
        elif cpu_choice == 'spock':
            print("Cpu chooses spock, player chooses paper.")
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses scissors.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses scissors.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses scissors.")
        elif cpu_choice == 'lizard':
            print("Cpu chooses lizard, player chooses scissors.")
        elif cpu_choice == 'spock':
            print("Cpu chooses spock, player chooses scissors.")
    elif player_choice == 'lizard':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses lizard.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses lizard.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses lizard.")
        elif cpu_choice == 'lizard':
            print("Cpu chooses lizard, player chooses lizard.")
        elif cpu_choice == 'spock':
            print("Cpu chooses spock, player chooses lizard.")
    elif player_choice == 'spock':
        if cpu_choice == 'rock':
            print("Cpu chooses rock, player chooses spock.")
        elif cpu_choice == 'paper':
            print("Cpu chooses paper, player chooses spock.")
        elif cpu_choice == 'scissors':
            print("Cpu chooses scissors, player chooses spock.")
        elif cpu_choice == 'lizard':
            print("Cpu chooses lizard, player chooses spock.")
        elif cpu_choice == 'spock':
            print("Cpu chooses spock, player chooses spock.")

while n <= rounds_to_win:
    n_rounds = number_rounds()
    cpu_choice = CPU_choice()
    player_choice = PLAYER_choice()
    winner = winner_round(cpu_choice, player_choice)
    print_winner_round()
    n += 1
    if player_choice == 'rock':
        if cpu_choice == 'rock':
            print("This round is a tie.")
        elif cpu_choice == 'paper':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'scissors':
            print("Player wins this round.")
            player_score += 1
    elif player_choice == 'paper':
        if cpu_choice == 'rock':
            print("Player wins this round.")
            player_score += 1
        elif cpu_choice == 'paper':
            print("This round is a tie.")
        elif cpu_choice == 'scissors':
            print("Cpu wins this round.")
            cpu_score += 1
    elif player_choice == 'scissors':
        if cpu_choice == 'rock':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'paper':
            print("Player wins this round.")
            player_score += 1
        elif cpu_choice == 'scissors':
            print("This round is a tie.")
    elif player_choice == 'lizard':
        if cpu_choice == 'rock':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'paper':
            print("Player wins this round.")
            player_score += 1
        elif cpu_choice == 'scissors':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'lizard':
            print("This round is a tie.")
        elif cpu_choice == 'spock':
            print("Player wins this round.")
            player_score += 1
    elif player_choice == 'spock':
        if cpu_choice == 'rock':
            print("Player wins this round.")
            player_score += 1
        elif cpu_choice == 'paper':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'scissors':
            print("Player wins this round.")
            player_score += 1
        elif cpu_choice == 'lizard':
            print("Cpu wins this round.")
            cpu_score += 1
        elif cpu_choice == 'spock':
            print("This round is a tie.")
    elif cpu_score == rounds_to_win:
            print("Cpu wins the game.")
    elif player_score == rounds_to_win:
            print("Player wins the game.")
